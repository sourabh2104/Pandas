# %%
# Pandas Advance!!

# %%
import pandas as pd
import numpy as np

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/57524  2144427120
# 1   https://github.com/pandas-dev/pandas/issues/57523  2144203549
# 2     https://github.com/pandas-dev/pandas/pull/57522  2144190572
# 3   https://github.com/pandas-dev/pandas/issues/57521  2144084011
# 4   https://github.com/pandas-dev/pandas/issues/57520  2144040421
# 5     https://github.com/pandas-dev/pandas/pull/57519  2144037974
# 6     https://github.com/pandas-dev/pandas/pull/57518  2143649322
# 7   https://github.com/pandas-dev/pandas/issues/57517  2143376452
# 8     https://github.com/pandas-dev/pandas/pull/57516  2143360560
# 9   https://github.com/pandas-dev/pandas/issues/57512  2143259336
# 10  https://github.com/pandas-dev/pandas/issues/57511  2143220186
# 11    https://github.com/pandas-dev/pandas/pull/57510  2143218042
# 12    https://github.com/pandas-dev/pandas/pull/57508  2142894312
# 13  https://github.com/pandas-dev/pandas/issues/57505  2142533685
# 14    https://github.com/pandas-dev/pandas/pull/57504  2142090284
# 15  https://github.com/pandas-dev/pandas/issues/57500  2141564011
# 16    https://github.com/pandas-dev/pandas/pull/57494  2141248587
# 17    https://github.com/pandas-dev/pandas/pull/57492  2141207431
# 18    https://github.com/pandas-dev/pandas/pull/57491  2141204830
# 19    https://github.com/pandas-dev/pandas/pull/57489  2141183560
# 20    https://github.com/pandas-dev/pandas/pull/57487  2141087697
# 21    https://github.com/pandas-dev/pandas/pull/57479  2140668961
# 22    https://github.com/pandas-dev/pandas/pull/57478  2140653286
# 23    https://github.com/pandas-dev/pandas/pull/57476  2140635039
# 24    https://github.com/pandas-dev/pandas/pull/57475  2140629857
# 25    https://github.com/pandas-dev/pandas/pull/57471  2140109143
# 26    https://github.com/pandas-dev/pandas/pull/57469  2139979734
# 27    https://github.com/pandas-dev/pandas/pull/57467  2139718597
# 28  https://github.com/pandas-dev/pandas/issues/57463  2139468884
# 29    https://github.com/pandas-dev/pandas/pull/57462  2139259674
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85_0Vxw   57524
# 1    I_kwDOAA0YD85_zfMd   57523
# 2   PR_kwDOAA0YD85nYprW   57522
# 3    I_kwDOAA0YD85_zCAr   57521
# 4    I_kwDOAA0YD85_y3Xl   57520
# 5   PR_kwDOAA0YD85nYIKp   57519
# 6   PR_kwDOAA0YD85nWzJN   57518
# 7    I_kwDOAA0YD85_wVRE   57517
# 8   PR_kwDOAA0YD85nV1LZ   57516
# 9    I_kwDOAA0YD85_v4rI   57512
# 10   I_kwDOAA0YD85_vvHa   57511
# 11  PR_kwDOAA0YD85nVWvz   57510
# 12  PR_kwDOAA0YD85nUQR1   57508
# 13   I_kwDOAA0YD85_tHg1   57505
# 14  PR_kwDOAA0YD85nRfve   57504
# 15   I_kwDOAA0YD85_paxr   57500
# 16  PR_kwDOAA0YD85nOngy   57494
# 17  PR_kwDOAA0YD85nOfS4   57492
# 18  PR_kwDOAA0YD85nOexQ   57491
# 19  PR_kwDOAA0YD85nOae-   57489
# 20  PR_kwDOAA0YD85nOHeA   57487
# 21  PR_kwDOAA0YD85nMwkG   57479
# 22  PR_kwDOAA0YD85nMtmU   57478
# 23  PR_kwDOAA0YD85nMqFf   57476
# 24  PR_kwDOAA0YD85nMpGU   57475
# 25  PR_kwDOAA0YD85nKxQk   57471
# 26  PR_kwDOAA0YD85nKT7e   57469
# 27  PR_kwDOAA0YD85nJb-B   57467
# 28   I_kwDOAA0YD85_hbRU   57463
# 29  PR_kwDOAA0YD85nH18V   57462
#
#                                                 title  ... closed_at  \
# 0   BUG: Subtraction fails with matching index of ...  ...       NaT
# 1   BUG: Test failures on 32-bit x86 with pyarrow ...  ...       NaT
# 2   TYP: fix mypy failures on main in pandas/core/...  ...       NaT
# 3   BUG: pandas >= 2.0 parses 'May' in ambiguous way.  ...       NaT
# 4   Potential performance regression by commit 1e9...  ...       NaT
# 5   TST: add a test for selecting columns in DataF...  ...       NaT
# 6                       Improving function definition  ...       NaT
# 7   BUG: MultiIndex.factorize fails if index is 0-...  ...       NaT
# 8                 CI/TST: Use tmp_path for excel test  ...       NaT
# 9       BUG: Unexpected read_csv parse_dates behavior  ...       NaT
# 10         CI: excel tests started failing on windows  ...       NaT
# 11                            DOC: Fix xarray example  ...       NaT
# 12                    BUG: Tick division is incorrect  ...       NaT
# 13  BUG: `std` using `numpy.float32` dtype gives i...  ...       NaT
# 14    DOC: Fix PR01 errors in multiple files (#57438)  ...       NaT
# 15  BUG: Columns resulting from joining multiIndex...  ...       NaT
# 16  BUG: DateTimeIndex.is_year_start unexpected be...  ...       NaT
# 17  Remove dtype inference on object dtype indexes...  ...       NaT
# 18                         Remove is_foo_dtype checks  ...       NaT
# 19  REGR: astype introducing decimals when casting...  ...       NaT
# 20  CoW: Track references in unstack if there is n...  ...       NaT
# 21  PERF: Improve performance for fillna with date...  ...       NaT
# 22       PERF: Improve performance for astype is view  ...       NaT
# 23         TYP: simplify read_csv/fwf/table overloads  ...       NaT
# 24  REGR: Index.map adding back tz to tz-agnostic ...  ...       NaT
# 25  BUG: guess_datetime_format fails to infer time...  ...       NaT
# 26          DEPR: to_pytimedelta return Index[object]  ...       NaT
# 27  PERF: RangeIndex.append returns a RangeIndex w...  ...       NaT
# 28  DEPR: to_pytimedelta to return Index[object] i...  ...       NaT
# 29  REGR: Behavior differs when adding Series to f...  ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1         CONTRIBUTOR                NaN
# 2         CONTRIBUTOR                NaN
# 3                NONE                NaN
# 4              MEMBER                NaN
# 5         CONTRIBUTOR                NaN
# 6                NONE                NaN
# 7         CONTRIBUTOR                NaN
# 8              MEMBER                NaN
# 9                NONE                NaN
# 10             MEMBER                NaN
# 11             MEMBER                NaN
# 12             MEMBER                NaN
# 13               NONE                NaN
# 14               NONE                NaN
# 15               NONE                NaN
# 16               NONE                NaN
# 17             MEMBER                NaN
# 18             MEMBER                NaN
# 19             MEMBER                NaN
# 20             MEMBER                NaN
# 21             MEMBER                NaN
# 22             MEMBER                NaN
# 23             MEMBER                NaN
# 24             MEMBER                NaN
# 25        CONTRIBUTOR                NaN
# 26               NONE                NaN
# 27             MEMBER                NaN
# 28             MEMBER                NaN
# 29             MEMBER                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\r\n\r\n- [X] I have ...
# 1   ### Pandas version checks\n\n- [X] I have chec...
# 2   fixed `mypy` failure on main in `pandas/core/g...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4   PR #57445 \r\n\r\nBenchmarks:\r\n\r\n- [ ] `gr...
# 5   - [x] closes #57457\r\n \r\nadded a test in to...
# 6   - [x] closes #57305 \r\n- [x] All [code checks...
# 7   ### Pandas version checks\n\n- [X] I have chec...
# 8   - [ ] closes #57511 (Replace xxxx with the Git...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  some issues with concurrent access to the same...
# 11  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 12  - [ ] closes #57264 (Replace xxxx with the Git...
# 13  ### Pandas version checks\r\n\r\n- [X] I have ...
# 14  Fixed PR01 errors (#57438) and added parameter...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  - [ ] closes #57377\r\n- [ ] [Tests added and ...
# 17  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 18  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 19  …\r\n\r\n- [ ] closes #57418 (Replace xxxx wit...
# 20  - [ ] xref #56633\r\n- [ ] All [code checks pa...
# 21  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 22  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 23                                               None
# 24  - [x] closes #57192 (Replace xxxx with the Git...
# 25  - [x] closes #57452(Replace xxxx with the GitH...
# 26  - [x] closes #57463 \r\n- [ ] [Tests added and...
# 27  Discovered in https://github.com/pandas-dev/pa...
# 28  https://github.com/pandas-dev/pandas/pull/5245...
# 29  follow up to #56426\r\n\r\nthis was inconsiste...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   NaN
# 2                       NaN           NaN   0.0
# 3                       NaN           NaN   NaN
# 4                       NaN           NaN   NaN
# 5                       NaN           NaN   0.0
# 6                       NaN           NaN   0.0
# 7                       NaN           NaN   NaN
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   NaN
# 10                      NaN           NaN   NaN
# 11                      NaN           NaN   0.0
# 12                      NaN           NaN   0.0
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   0.0
# 15                      NaN           NaN   NaN
# 16                      NaN           NaN   0.0
# 17                      NaN           NaN   0.0
# 18                      NaN           NaN   0.0
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   0.0
# 21                      NaN           NaN   0.0
# 22                      NaN           NaN   0.0
# 23                      NaN           NaN   0.0
# 24                      NaN           NaN   1.0
# 25                      NaN           NaN   0.0
# 26                      NaN           NaN   0.0
# 27                      NaN           NaN   0.0
# 28                      NaN           NaN   NaN
# 29                      NaN           NaN   0.0
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
# [30 rows x 30 columns]

# %%
import requests
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df = data.json()

# %%
len(df)
# Out:
# 30

# %%
for i in range(len(df)):
    print(df[i]['user']['node_id'])
# Out:
# MDQ6VXNlcjkwMjQ2MjEz
# MDQ6VXNlcjExMDc2NQ==
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjEyMTg3OTQ5
# MDQ6VXNlcjExODM1MjQ2
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjI4NTc0MDIz
# MDQ6VXNlcjE4NDg4
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjg2MTkwMQ==
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjc4NDE3MDE=
# MDQ6VXNlcjgwMjM4ODcx
# MDQ6VXNlcjYzNTAwMjc=
# U_kgDOBaGsqw
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjQ3MDMyNTYz
# MDQ6VXNlcjcwMjIwNzYw
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjYxOTM0NzQ0

# %%
pd.DataFrame(df)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/57524  2144427120
# 1   https://github.com/pandas-dev/pandas/issues/57523  2144203549
# 2     https://github.com/pandas-dev/pandas/pull/57522  2144190572
# 3   https://github.com/pandas-dev/pandas/issues/57521  2144084011
# 4   https://github.com/pandas-dev/pandas/issues/57520  2144040421
# 5     https://github.com/pandas-dev/pandas/pull/57519  2144037974
# 6     https://github.com/pandas-dev/pandas/pull/57518  2143649322
# 7   https://github.com/pandas-dev/pandas/issues/57517  2143376452
# 8     https://github.com/pandas-dev/pandas/pull/57516  2143360560
# 9   https://github.com/pandas-dev/pandas/issues/57512  2143259336
# 10  https://github.com/pandas-dev/pandas/issues/57511  2143220186
# 11    https://github.com/pandas-dev/pandas/pull/57510  2143218042
# 12    https://github.com/pandas-dev/pandas/pull/57508  2142894312
# 13  https://github.com/pandas-dev/pandas/issues/57505  2142533685
# 14    https://github.com/pandas-dev/pandas/pull/57504  2142090284
# 15  https://github.com/pandas-dev/pandas/issues/57500  2141564011
# 16    https://github.com/pandas-dev/pandas/pull/57494  2141248587
# 17    https://github.com/pandas-dev/pandas/pull/57492  2141207431
# 18    https://github.com/pandas-dev/pandas/pull/57491  2141204830
# 19    https://github.com/pandas-dev/pandas/pull/57489  2141183560
# 20    https://github.com/pandas-dev/pandas/pull/57487  2141087697
# 21    https://github.com/pandas-dev/pandas/pull/57479  2140668961
# 22    https://github.com/pandas-dev/pandas/pull/57478  2140653286
# 23    https://github.com/pandas-dev/pandas/pull/57476  2140635039
# 24    https://github.com/pandas-dev/pandas/pull/57475  2140629857
# 25    https://github.com/pandas-dev/pandas/pull/57471  2140109143
# 26    https://github.com/pandas-dev/pandas/pull/57469  2139979734
# 27    https://github.com/pandas-dev/pandas/pull/57467  2139718597
# 28  https://github.com/pandas-dev/pandas/issues/57463  2139468884
# 29    https://github.com/pandas-dev/pandas/pull/57462  2139259674
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85_0Vxw   57524
# 1    I_kwDOAA0YD85_zfMd   57523
# 2   PR_kwDOAA0YD85nYprW   57522
# 3    I_kwDOAA0YD85_zCAr   57521
# 4    I_kwDOAA0YD85_y3Xl   57520
# 5   PR_kwDOAA0YD85nYIKp   57519
# 6   PR_kwDOAA0YD85nWzJN   57518
# 7    I_kwDOAA0YD85_wVRE   57517
# 8   PR_kwDOAA0YD85nV1LZ   57516
# 9    I_kwDOAA0YD85_v4rI   57512
# 10   I_kwDOAA0YD85_vvHa   57511
# 11  PR_kwDOAA0YD85nVWvz   57510
# 12  PR_kwDOAA0YD85nUQR1   57508
# 13   I_kwDOAA0YD85_tHg1   57505
# 14  PR_kwDOAA0YD85nRfve   57504
# 15   I_kwDOAA0YD85_paxr   57500
# 16  PR_kwDOAA0YD85nOngy   57494
# 17  PR_kwDOAA0YD85nOfS4   57492
# 18  PR_kwDOAA0YD85nOexQ   57491
# 19  PR_kwDOAA0YD85nOae-   57489
# 20  PR_kwDOAA0YD85nOHeA   57487
# 21  PR_kwDOAA0YD85nMwkG   57479
# 22  PR_kwDOAA0YD85nMtmU   57478
# 23  PR_kwDOAA0YD85nMqFf   57476
# 24  PR_kwDOAA0YD85nMpGU   57475
# 25  PR_kwDOAA0YD85nKxQk   57471
# 26  PR_kwDOAA0YD85nKT7e   57469
# 27  PR_kwDOAA0YD85nJb-B   57467
# 28   I_kwDOAA0YD85_hbRU   57463
# 29  PR_kwDOAA0YD85nH18V   57462
#
#                                                 title  ... closed_at  \
# 0   BUG: Subtraction fails with matching index of ...  ...      None
# 1   BUG: Test failures on 32-bit x86 with pyarrow ...  ...      None
# 2   TYP: fix mypy failures on main in pandas/core/...  ...      None
# 3   BUG: pandas >= 2.0 parses 'May' in ambiguous way.  ...      None
# 4   Potential performance regression by commit 1e9...  ...      None
# 5   TST: add a test for selecting columns in DataF...  ...      None
# 6                       Improving function definition  ...      None
# 7   BUG: MultiIndex.factorize fails if index is 0-...  ...      None
# 8                 CI/TST: Use tmp_path for excel test  ...      None
# 9       BUG: Unexpected read_csv parse_dates behavior  ...      None
# 10         CI: excel tests started failing on windows  ...      None
# 11                            DOC: Fix xarray example  ...      None
# 12                    BUG: Tick division is incorrect  ...      None
# 13  BUG: `std` using `numpy.float32` dtype gives i...  ...      None
# 14    DOC: Fix PR01 errors in multiple files (#57438)  ...      None
# 15  BUG: Columns resulting from joining multiIndex...  ...      None
# 16  BUG: DateTimeIndex.is_year_start unexpected be...  ...      None
# 17  Remove dtype inference on object dtype indexes...  ...      None
# 18                         Remove is_foo_dtype checks  ...      None
# 19  REGR: astype introducing decimals when casting...  ...      None
# 20  CoW: Track references in unstack if there is n...  ...      None
# 21  PERF: Improve performance for fillna with date...  ...      None
# 22       PERF: Improve performance for astype is view  ...      None
# 23         TYP: simplify read_csv/fwf/table overloads  ...      None
# 24  REGR: Index.map adding back tz to tz-agnostic ...  ...      None
# 25  BUG: guess_datetime_format fails to infer time...  ...      None
# 26          DEPR: to_pytimedelta return Index[object]  ...      None
# 27  PERF: RangeIndex.append returns a RangeIndex w...  ...      None
# 28  DEPR: to_pytimedelta to return Index[object] i...  ...      None
# 29  REGR: Behavior differs when adding Series to f...  ...      None
#
#    author_association active_lock_reason  \
# 0                NONE               None
# 1         CONTRIBUTOR               None
# 2         CONTRIBUTOR               None
# 3                NONE               None
# 4              MEMBER               None
# 5         CONTRIBUTOR               None
# 6                NONE               None
# 7         CONTRIBUTOR               None
# 8              MEMBER               None
# 9                NONE               None
# 10             MEMBER               None
# 11             MEMBER               None
# 12             MEMBER               None
# 13               NONE               None
# 14               NONE               None
# 15               NONE               None
# 16               NONE               None
# 17             MEMBER               None
# 18             MEMBER               None
# 19             MEMBER               None
# 20             MEMBER               None
# 21             MEMBER               None
# 22             MEMBER               None
# 23             MEMBER               None
# 24             MEMBER               None
# 25        CONTRIBUTOR               None
# 26               NONE               None
# 27             MEMBER               None
# 28             MEMBER               None
# 29             MEMBER               None
#
#                                                  body  \
# 0   ### Pandas version checks\r\n\r\n- [X] I have ...
# 1   ### Pandas version checks\n\n- [X] I have chec...
# 2   fixed `mypy` failure on main in `pandas/core/g...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4   PR #57445 \r\n\r\nBenchmarks:\r\n\r\n- [ ] `gr...
# 5   - [x] closes #57457\r\n \r\nadded a test in to...
# 6   - [x] closes #57305 \r\n- [x] All [code checks...
# 7   ### Pandas version checks\n\n- [X] I have chec...
# 8   - [ ] closes #57511 (Replace xxxx with the Git...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  some issues with concurrent access to the same...
# 11  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 12  - [ ] closes #57264 (Replace xxxx with the Git...
# 13  ### Pandas version checks\r\n\r\n- [X] I have ...
# 14  Fixed PR01 errors (#57438) and added parameter...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  - [ ] closes #57377\r\n- [ ] [Tests added and ...
# 17  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 18  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 19  …\r\n\r\n- [ ] closes #57418 (Replace xxxx wit...
# 20  - [ ] xref #56633\r\n- [ ] All [code checks pa...
# 21  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 22  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 23                                               None
# 24  - [x] closes #57192 (Replace xxxx with the Git...
# 25  - [x] closes #57452(Replace xxxx with the GitH...
# 26  - [x] closes #57463 \r\n- [ ] [Tests added and...
# 27  Discovered in https://github.com/pandas-dev/pa...
# 28  https://github.com/pandas-dev/pandas/pull/5245...
# 29  follow up to #56426\r\n\r\nthis was inconsiste...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason  draft  \
# 0                      None          None    NaN
# 1                      None          None    NaN
# 2                      None          None  False
# 3                      None          None    NaN
# 4                      None          None    NaN
# 5                      None          None  False
# 6                      None          None  False
# 7                      None          None    NaN
# 8                      None          None  False
# 9                      None          None    NaN
# 10                     None          None    NaN
# 11                     None          None  False
# 12                     None          None  False
# 13                     None          None    NaN
# 14                     None          None  False
# 15                     None          None    NaN
# 16                     None          None  False
# 17                     None          None  False
# 18                     None          None  False
# 19                     None          None  False
# 20                     None          None  False
# 21                     None          None  False
# 22                     None          None  False
# 23                     None          None  False
# 24                     None          None   True
# 25                     None          None  False
# 26                     None          None  False
# 27                     None          None  False
# 28                     None          None    NaN
# 29                     None          None  False
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
# [30 rows x 30 columns]

# %%
df=pd.DataFrame(df,columns = ['user', 'timeline_url'])

# %%
df.to_csv('json_info.csv')

# %%
df
# Out:
#                                                  user  \
# 0   {'login': 'Bjoern-Rapp', 'id': 90246213, 'node...
# 1   {'login': 'mgorny', 'id': 110765, 'node_id': '...
# 2   {'login': 'natmokval', 'id': 91160475, 'node_i...
# 3   {'login': 'ffyring', 'id': 12187949, 'node_id'...
# 4   {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 5   {'login': 'natmokval', 'id': 91160475, 'node_i...
# 6   {'login': 'jmarintur', 'id': 28574023, 'node_i...
# 7   {'login': 'batterseapower', 'id': 18488, 'node...
# 8   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 9   {'login': 'kounoupis', 'id': 861901, 'node_id'...
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 12  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 13  {'login': 'jamespreed', 'id': 7841701, 'node_i...
# 14  {'login': 'Deen-dot', 'id': 80238871, 'node_id...
# 15  {'login': 'yuji38kwmt', 'id': 6350027, 'node_i...
# 16  {'login': 'mattheeter', 'id': 94481579, 'node_...
# 17  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 18  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 19  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 20  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 21  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 22  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 23  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 24  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 25  {'login': 'yuanx749', 'id': 47032563, 'node_id...
# 26  {'login': 'lamdang2k', 'id': 70220760, 'node_i...
# 27  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 28  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 29  {'login': 'phofl', 'id': 61934744, 'node_id': ...
#
#                                          timeline_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
# Solving the dataset!!
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() # it describes the numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[df.columns[df.dtypes == 'object']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[df.dtypes[df.dtypes != 'object'].index]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df[df.columns[df.dtypes == 'object']].describe
# Out:
# <bound method NDFrame.describe of                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]>

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[1:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df[10:100]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..          ...       ...     ...                                   ...
# 95           96         0       3           Shorney, Mr. Charles Joseph
# 96           97         0       1             Goldschmidt, Mr. George B
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99          100         0       2                     Kantor, Mr. Sinai
#
#        Sex   Age  SibSp  Parch     Ticket     Fare    Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000       G6        S
# 11  female  58.0      0      0     113783  26.5500     C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500      NaN        S
# 13    male  39.0      1      5     347082  31.2750      NaN        S
# 14  female  14.0      0      0     350406   7.8542      NaN        S
# ..     ...   ...    ...    ...        ...      ...      ...      ...
# 95    male   NaN      0      0     374910   8.0500      NaN        S
# 96    male  71.0      0      0   PC 17754  34.6542       A5        C
# 97    male  23.0      0      1   PC 17759  63.3583  D10 D12        C
# 98  female  34.0      0      1     231919  23.0000      NaN        S
# 99    male  34.0      1      0     244367  26.0000      NaN        S
#
# [90 rows x 12 columns]

# %%
df[10:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# 62           63         0       1
# 64           65         0       1
# 66           67         1       2
# 68           69         1       3
# 70           71         0       2
# 72           73         0       2
# 74           75         1       3
# 76           77         0       3
# 78           79         1       2
# 80           81         0       3
# 82           83         1       3
# 84           85         1       2
# 86           87         0       3
# 88           89         1       1
# 90           91         0       3
# 92           93         0       1
# 94           95         0       3
# 96           97         0       1
# 98           99         1       2
#
#                                                  Name     Sex    Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 12                     Saundercock, Mr. William Henry    male  20.00      0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0
# 16                               Rice, Master. Eugene    male   2.00      4
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# 20                               Fynney, Mr. Joseph J    male  35.00      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.00      0
# 24                      Palsson, Miss. Torborg Danira  female   8.00      3
# 26                            Emir, Mr. Farred Chehab    male    NaN      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female    NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.00      0
# 32                           Glynn, Miss. Mary Agatha  female    NaN      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.00      1
# 36                                   Mamee, Mr. Hanna    male    NaN      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.00      2
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00      1
# 42                                Kraeff, Mr. Theodor    male    NaN      0
# 44                      Devaney, Miss. Margaret Delia  female  19.00      0
# 46                                  Lennon, Mr. Denis    male    NaN      1
# 48                                Samaan, Mr. Youssef    male    NaN      2
# 50                         Panula, Master. Juha Niilo    male   7.00      4
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.00      0
# 56                                  Rugg, Miss. Emily  female  21.00      0
# 58                       West, Miss. Constance Mirium  female   5.00      1
# 60                              Sirayanian, Mr. Orsen    male  22.00      0
# 62                        Harris, Mr. Henry Birkhardt    male  45.00      1
# 64                              Stewart, Mr. Albert A    male    NaN      0
# 66                       Nye, Mrs. (Elizabeth Ramell)  female  29.00      0
# 68                    Andersson, Miss. Erna Alexandra  female  17.00      4
# 70                         Jenkin, Mr. Stephen Curnow    male  32.00      0
# 72                               Hood, Mr. Ambrose Jr    male  21.00      0
# 74                                      Bing, Mr. Lee    male  32.00      0
# 76                                  Staneff, Mr. Ivan    male    NaN      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
# 80                               Waelens, Mr. Achille    male  22.00      0
# 82                     McDermott, Miss. Brigdet Delia  female    NaN      0
# 84                                Ilett, Miss. Bertha  female  17.00      0
# 86                             Ford, Mr. William Neal    male  16.00      1
# 88                         Fortune, Miss. Mabel Helen  female  23.00      3
# 90                               Christmann, Mr. Emil    male  29.00      0
# 92                        Chaffee, Mr. Herbert Fuller    male  46.00      1
# 94                                  Coxon, Mr. Daniel    male  59.00      0
# 96                          Goldschmidt, Mr. George B    male  71.00      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.00      0
#
#     Parch        Ticket      Fare        Cabin Embarked
# 10      1       PP 9549   16.7000           G6        S
# 12      0     A/5. 2151    8.0500          NaN        S
# 14      0        350406    7.8542          NaN        S
# 16      1        382652   29.1250          NaN        Q
# 18      0        345763   18.0000          NaN        S
# 20      0        239865   26.0000          NaN        S
# 22      0        330923    8.0292          NaN        Q
# 24      1        349909   21.0750          NaN        S
# 26      0          2631    7.2250          NaN        C
# 28      0        330959    7.8792          NaN        Q
# 30      0      PC 17601   27.7208          NaN        C
# 32      0        335677    7.7500          NaN        Q
# 34      0      PC 17604   82.1708          NaN        C
# 36      0          2677    7.2292          NaN        C
# 38      0        345764   18.0000          NaN        S
# 40      0          7546    9.4750          NaN        S
# 42      0        349253    7.8958          NaN        C
# 44      0        330958    7.8792          NaN        Q
# 46      0        370371   15.5000          NaN        Q
# 48      0          2662   21.6792          NaN        C
# 50      1       3101295   39.6875          NaN        S
# 52      0      PC 17572   76.7292          D33        C
# 54      1        113509   61.9792          B30        C
# 56      0    C.A. 31026   10.5000          NaN        S
# 58      2    C.A. 34651   27.7500          NaN        S
# 60      0          2669    7.2292          NaN        C
# 62      0         36973   83.4750          C83        S
# 64      0      PC 17605   27.7208          NaN        C
# 66      0    C.A. 29395   10.5000          F33        S
# 68      2       3101281    7.9250          NaN        S
# 70      0    C.A. 33111   10.5000          NaN        S
# 72      0  S.O.C. 14879   73.5000          NaN        S
# 74      0          1601   56.4958          NaN        S
# 76      0        349208    7.8958          NaN        S
# 78      2        248738   29.0000          NaN        S
# 80      0        345767    9.0000          NaN        S
# 82      0        330932    7.7875          NaN        Q
# 84      0    SO/C 14885   10.5000          NaN        S
# 86      3    W./C. 6608   34.3750          NaN        S
# 88      2         19950  263.0000  C23 C25 C27        S
# 90      0        343276    8.0500          NaN        S
# 92      0   W.E.P. 5734   61.1750          E31        S
# 94      0        364500    7.2500          NaN        S
# 96      0      PC 17754   34.6542           A5        C
# 98      1        231919   23.0000          NaN        S

# %%
df[10:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 45                           Rogers, Mr. William John    male   NaN      0
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 60                              Sirayanian, Mr. Orsen    male  22.0      0
# 65                           Moubarek, Master. Gerios    male   NaN      1
# 70                         Jenkin, Mr. Stephen Curnow    male  32.0      0
# 75                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 80                               Waelens, Mr. Achille    male  22.0      0
# 85  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 90                               Christmann, Mr. Emil    male  29.0      0
# 95                        Shorney, Mr. Charles Joseph    male   NaN      0
#
#     Parch           Ticket     Fare  Cabin Embarked
# 10      1          PP 9549  16.7000     G6        S
# 15      0           248706  16.0000    NaN        S
# 20      0           239865  26.0000    NaN        S
# 25      5           347077  31.3875    NaN        S
# 30      0         PC 17601  27.7208    NaN        C
# 35      0           113789  52.0000    NaN        S
# 40      0             7546   9.4750    NaN        S
# 45      0  S.C./A.4. 23567   8.0500    NaN        S
# 50      1          3101295  39.6875    NaN        S
# 55      0            19947  35.5000    C52        S
# 60      0             2669   7.2292    NaN        C
# 65      1             2661  15.2458    NaN        C
# 70      0       C.A. 33111  10.5000    NaN        S
# 75      0           348123   7.6500  F G73        S
# 80      0           345767   9.0000    NaN        S
# 85      0          3101278  15.8500    NaN        S
# 90      0           343276   8.0500    NaN        S
# 95      0           374910   8.0500    NaN        S

# %%
 df['new_col']= 'sourabh'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col
# 0        0         A/5 21171   7.2500   NaN        S  sourabh
# 1        0          PC 17599  71.2833   C85        C  sourabh
# 2        0  STON/O2. 3101282   7.9250   NaN        S  sourabh
# 3        0            113803  53.1000  C123        S  sourabh
# 4        0            373450   8.0500   NaN        S  sourabh
# ..     ...               ...      ...   ...      ...      ...
# 886      0            211536  13.0000   NaN        S  sourabh
# 887      0            112053  30.0000   B42        S  sourabh
# 888      2        W./C. 6607  23.4500   NaN        S  sourabh
# 889      0            111369  30.0000  C148        C  sourabh
# 890      0            370376   7.7500   NaN        Q  sourabh
#
# [891 rows x 13 columns]

# %%
df['family']= df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  \
# 0        0         A/5 21171   7.2500   NaN        S  sourabh         1
# 1        0          PC 17599  71.2833   C85        C  sourabh         1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  sourabh         0
# 3        0            113803  53.1000  C123        S  sourabh         1
# 4        0            373450   8.0500   NaN        S  sourabh         0
# ..     ...               ...      ...   ...      ...      ...       ...
# 886      0            211536  13.0000   NaN        S  sourabh         0
# 887      0            112053  30.0000   B42        S  sourabh         0
# 888      2        W./C. 6607  23.4500   NaN        S  sourabh         3
# 889      0            111369  30.0000  C148        C  sourabh         0
# 890      0            370376   7.7500   NaN        Q  sourabh         0
#
#      family
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [891 rows x 15 columns]

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  \
# 0        0         A/5 21171   7.2500   NaN        S  sourabh         1
# 1        0          PC 17599  71.2833   C85        C  sourabh         1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  sourabh         0
# 3        0            113803  53.1000  C123        S  sourabh         1
# 4        0            373450   8.0500   NaN        S  sourabh         0
# ..     ...               ...      ...   ...      ...      ...       ...
# 886      0            211536  13.0000   NaN        S  sourabh         0
# 887      0            112053  30.0000   B42        S  sourabh         0
# 888      2        W./C. 6607  23.4500   NaN        S  sourabh         3
# 889      0            111369  30.0000  C148        C  sourabh         0
# 890      0            370376   7.7500   NaN        Q  sourabh         0
#
#      family
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  family
# 0      0         A/5 21171   7.2500   NaN        S  sourabh         1       1
# 1      0          PC 17599  71.2833   C85        C  sourabh         1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  sourabh         0       0
# 3      0            113803  53.1000  C123        S  sourabh         1       1
# 4      0            373450   8.0500   NaN        S  sourabh         0       0

# %%
# How many passengers are less than 5 years old?

df[df['Age'] < 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 193          194         1       2                Navratil, Master. Michel M
# 205          206         0       3                Strom, Miss. Telma Matilda
# 261          262         1       3         Asplund, Master. Edvin Rojj Felix
# 297          298         0       1              Allison, Miss. Helen Loraine
# 305          306         1       1            Allison, Master. Hudson Trevor
# 340          341         1       2            Navratil, Master. Edmond Roger
# 348          349         1       3    Coutts, Master. William Loch "William"
# 374          375         0       3                Palsson, Miss. Stina Viola
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 386          387         0       3           Goodwin, Master. Sidney Leonard
# 407          408         1       2            Richards, Master. William Rowe
# 445          446         1       1                 Dodge, Master. Washington
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 530          531         1       2                  Quick, Miss. Phyllis May
# 618          619         1       2               Becker, Miss. Marion Louise
# 642          643         0       3             Skoog, Miss. Margit Elizabeth
# 644          645         1       3                    Baclini, Miss. Eugenie
# 691          692         1       3                        Karun, Miss. Manca
# 750          751         1       2                         Wells, Miss. Joan
# 755          756         1       2                 Hamalainen, Master. Viljo
# 788          789         1       3                Dean, Master. Bertram Vere
# 803          804         1       3           Thomas, Master. Assad Alexander
# 824          825         0       3              Panula, Master. Urho Abraham
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 869          870         1       3           Johnson, Master. Harold Theodor
#
#         Sex   Age  SibSp  Parch           Ticket      Fare    Cabin Embarked  \
# 7      male  2.00      3      1           349909   21.0750      NaN        S
# 10   female  4.00      1      1          PP 9549   16.7000       G6        S
# 16     male  2.00      4      1           382652   29.1250      NaN        Q
# 43   female  3.00      1      2    SC/Paris 2123   41.5792      NaN        C
# 63     male  4.00      3      2           347088   27.9000      NaN        S
# 78     male  0.83      0      2           248738   29.0000      NaN        S
# 119  female  2.00      4      2           347082   31.2750      NaN        S
# 164    male  1.00      4      1          3101295   39.6875      NaN        S
# 171    male  4.00      4      1           382652   29.1250      NaN        Q
# 172  female  1.00      1      1           347742   11.1333      NaN        S
# 183    male  1.00      2      1           230136   39.0000       F4        S
# 184  female  4.00      0      2           315153   22.0250      NaN        S
# 193    male  3.00      1      1           230080   26.0000       F2        S
# 205  female  2.00      0      1           347054   10.4625       G6        S
# 261    male  3.00      4      2           347077   31.3875      NaN        S
# 297  female  2.00      1      2           113781  151.5500  C22 C26        S
# 305    male  0.92      1      2           113781  151.5500  C22 C26        S
# 340    male  2.00      1      1           230080   26.0000       F2        S
# 348    male  3.00      1      1       C.A. 37671   15.9000      NaN        S
# 374  female  3.00      3      1           349909   21.0750      NaN        S
# 381  female  1.00      0      2             2653   15.7417      NaN        C
# 386    male  1.00      5      2          CA 2144   46.9000      NaN        S
# 407    male  3.00      1      1            29106   18.7500      NaN        S
# 445    male  4.00      0      2            33638   81.8583      A34        S
# 469  female  0.75      2      1             2666   19.2583      NaN        C
# 479  female  2.00      0      1          3101298   12.2875      NaN        S
# 530  female  2.00      1      1            26360   26.0000      NaN        S
# 618  female  4.00      2      1           230136   39.0000       F4        S
# 642  female  2.00      3      2           347088   27.9000      NaN        S
# 644  female  0.75      2      1             2666   19.2583      NaN        C
# 691  female  4.00      0      1           349256   13.4167      NaN        C
# 750  female  4.00      1      1            29103   23.0000      NaN        S
# 755    male  0.67      1      1           250649   14.5000      NaN        S
# 788    male  1.00      1      2        C.A. 2315   20.5750      NaN        S
# 803    male  0.42      0      1             2625    8.5167      NaN        C
# 824    male  2.00      4      1          3101295   39.6875      NaN        S
# 827    male  1.00      0      2  S.C./PARIS 2079   37.0042      NaN        C
# 831    male  0.83      1      1            29106   18.7500      NaN        S
# 850    male  4.00      4      2           347082   31.2750      NaN        S
# 869    male  4.00      1      1           347742   11.1333      NaN        S
#
#      new_col  new_col1  family
# 7    sourabh         4       4
# 10   sourabh         2       2
# 16   sourabh         5       5
# 43   sourabh         3       3
# 63   sourabh         5       5
# 78   sourabh         2       2
# 119  sourabh         6       6
# 164  sourabh         5       5
# 171  sourabh         5       5
# 172  sourabh         2       2
# 183  sourabh         3       3
# 184  sourabh         2       2
# 193  sourabh         2       2
# 205  sourabh         1       1
# 261  sourabh         6       6
# 297  sourabh         3       3
# 305  sourabh         3       3
# 340  sourabh         2       2
# 348  sourabh         2       2
# 374  sourabh         4       4
# 381  sourabh         2       2
# 386  sourabh         7       7
# 407  sourabh         2       2
# 445  sourabh         2       2
# 469  sourabh         3       3
# 479  sourabh         1       1
# 530  sourabh         2       2
# 618  sourabh         3       3
# 642  sourabh         5       5
# 644  sourabh         3       3
# 691  sourabh         1       1
# 750  sourabh         2       2
# 755  sourabh         2       2
# 788  sourabh         3       3
# 803  sourabh         1       1
# 824  sourabh         5       5
# 827  sourabh         2       2
# 831  sourabh         2       2
# 850  sourabh         6       6
# 869  sourabh         2       2

# %%
len(df[df['Age'] < 5])
# Out:
# 40

# %%
# number of passenger >18

len(df[df['Age'] > 18])
# Out:
# 575

# %%
# how many passenger are 18 years old?

len(df) - len(df[df['Age'] > 18])
# Out:
# 316

# %%
len(df[df['Age'] <=18])
# Out:
# 139

# %%
# how many passengers have paid less than avg fare?

df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df['Fare'] <32
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']<df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      new_col  new_col1  family
# 0    sourabh         1       1
# 2    sourabh         0       0
# 4    sourabh         0       0
# 5    sourabh         0       0
# 7    sourabh         4       4
# ..       ...       ...     ...
# 886  sourabh         0       0
# 887  sourabh         0       0
# 888  sourabh         3       3
# 889  sourabh         0       0
# 890  sourabh         0       0
#
# [680 rows x 15 columns]

# %%
df[df['Fare'] < df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      new_col  new_col1  family
# 0    sourabh         1       1
# 2    sourabh         0       0
# 4    sourabh         0       0
# 5    sourabh         0       0
# 7    sourabh         4       4
# ..       ...       ...     ...
# 886  sourabh         0       0
# 887  sourabh         0       0
# 888  sourabh         3       3
# 889  sourabh         0       0
# 890  sourabh         0       0
#
# [680 rows x 15 columns]

# %%
len(df[df['Fare'] > df['Fare'].mean()])
# Out:
# 211

# %%
# How many passengers  paid 0 fare?

df['Fare']==0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked  new_col  new_col1  \
# 179  36.0      0      0    LINE   0.0   NaN        S  sourabh         0
# 263  40.0      0      0  112059   0.0   B94        S  sourabh         0
# 271  25.0      0      0    LINE   0.0   NaN        S  sourabh         0
# 277   NaN      0      0  239853   0.0   NaN        S  sourabh         0
# 302  19.0      0      0    LINE   0.0   NaN        S  sourabh         0
# 413   NaN      0      0  239853   0.0   NaN        S  sourabh         0
# 466   NaN      0      0  239853   0.0   NaN        S  sourabh         0
# 481   NaN      0      0  239854   0.0   NaN        S  sourabh         0
# 597  49.0      0      0    LINE   0.0   NaN        S  sourabh         0
# 633   NaN      0      0  112052   0.0   NaN        S  sourabh         0
# 674   NaN      0      0  239856   0.0   NaN        S  sourabh         0
# 732   NaN      0      0  239855   0.0   NaN        S  sourabh         0
# 806  39.0      0      0  112050   0.0   A36        S  sourabh         0
# 815   NaN      0      0  112058   0.0  B102        S  sourabh         0
# 822  38.0      0      0   19972   0.0   NaN        S  sourabh         0
#
#      family
# 179       0
# 263       0
# 271       0
# 277       0
# 302       0
# 413       0
# 466       0
# 481       0
# 597       0
# 633       0
# 674       0
# 732       0
# 806       0
# 815       0
# 822       0

# %%
list[df[df['Fare']==0].Name]
# Out:
# list[179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object]

# %%
# How mny passengers are male and female?

df['Sex']=="Male"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
len(df[df['Sex']=="male"])
# Out:
# 577

# %%
df['Sex']=="female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
len(df[df['Sex']=="female"])
# Out:
# 314

# %%
df['Sex'].value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
# how many passengers of class 1 ?

df[df['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked  new_col  new_col1  family
# 1        0  PC 17599  71.2833          C85        C  sourabh         1       1
# 3        0    113803  53.1000         C123        S  sourabh         1       1
# 6        0     17463  51.8625          E46        S  sourabh         0       0
# 11       0    113783  26.5500         C103        S  sourabh         0       0
# 23       0    113788  35.5000           A6        S  sourabh         0       0
# ..     ...       ...      ...          ...      ...      ...       ...     ...
# 871      1     11751  52.5542          D35        S  sourabh         2       2
# 872      0       695   5.0000  B51 B53 B55        S  sourabh         0       0
# 879      1     11767  83.1583          C50        C  sourabh         1       1
# 887      0    112053  30.0000          B42        S  sourabh         0       0
# 889      0    111369  30.0000         C148        C  sourabh         0       0
#
# [216 rows x 15 columns]

# %%
# how many passengers are survived ?

df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  \
# 1        0          PC 17599  71.2833   C85        C  sourabh         1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  sourabh         0
# 3        0            113803  53.1000  C123        S  sourabh         1
# 8        2            347742  11.1333   NaN        S  sourabh         2
# 9        0            237736  30.0708   NaN        C  sourabh         1
# ..     ...               ...      ...   ...      ...      ...       ...
# 875      0              2667   7.2250   NaN        C  sourabh         0
# 879      1             11767  83.1583   C50        C  sourabh         1
# 880      1            230433  26.0000   NaN        S  sourabh         1
# 887      0            112053  30.0000   B42        S  sourabh         0
# 889      0            111369  30.0000  C148        C  sourabh         0
#
#      family
# 1         1
# 2         0
# 3         1
# 8         2
# 9         1
# ..      ...
# 875       0
# 879       1
# 880       1
# 887       0
# 889       0
#
# [342 rows x 15 columns]

# %%
df['Survived'].value_counts(normalize =True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
# How many femals paid more than avg Fare ?

df['Sex']=='femal'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[(df['Sex']=='female') & (df['Fare']>df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch         Ticket      Fare Cabin Embarked  new_col  new_col1  family
# 1        0       PC 17599   71.2833   C85        C  sourabh         1       1
# 3        0         113803   53.1000  C123        S  sourabh         1       1
# 31       0       PC 17569  146.5208   B78        C  sourabh         1       1
# 43       2  SC/Paris 2123   41.5792   NaN        C  sourabh         3       3
# 52       0       PC 17572   76.7292   D33        C  sourabh         1       1
# ..     ...            ...       ...   ...      ...      ...       ...     ...
# 853      1       PC 17592   39.4000   D28        S  sourabh         1       1
# 856      1          36928  164.8667   NaN        S  sourabh         2       2
# 863      2       CA. 2343   69.5500   NaN        S  sourabh        10      10
# 871      1          11751   52.5542   D35        S  sourabh         2       2
# 879      1          11767   83.1583   C50        C  sourabh         1       1
#
# [104 rows x 15 columns]

# %%
#  How many passengers are male or who paid greater than avg fare ?

df[(df["Sex"]=='male') | (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  \
# 0        0         A/5 21171   7.2500   NaN        S  sourabh         1
# 1        0          PC 17599  71.2833   C85        C  sourabh         1
# 3        0            113803  53.1000  C123        S  sourabh         1
# 4        0            373450   8.0500   NaN        S  sourabh         0
# 5        0            330877   8.4583   NaN        Q  sourabh         0
# ..     ...               ...      ...   ...      ...      ...       ...
# 883      0  C.A./SOTON 34068  10.5000   NaN        S  sourabh         0
# 884      0   SOTON/OQ 392076   7.0500   NaN        S  sourabh         0
# 886      0            211536  13.0000   NaN        S  sourabh         0
# 889      0            111369  30.0000  C148        C  sourabh         0
# 890      0            370376   7.7500   NaN        Q  sourabh         0
#
#      family
# 0         1
# 1         1
# 3         1
# 4         0
# 5         0
# ..      ...
# 883       0
# 884       0
# 886       0
# 889       0
# 890       0
#
# [681 rows x 15 columns]

# %%
np.mean(df['Fare'])
# Out:
# 32.204207968574636

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df['Fare'])
# Out:
# 0.0

# %%
# Who are the passengers who paid maximum Fare ?

df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# How many passengers have parch greater than 3 ?

df[df['Parch'] > 3]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 25            26         1       3
# 167          168         0       3
# 360          361         0       3
# 438          439         0       1
# 567          568         0       3
# 610          611         0       3
# 638          639         0       3
# 678          679         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 360                                 Skoog, Mr. Wilhelm    male  40.0      1
# 438                                  Fortune, Mr. Mark    male  64.0      1
# 567        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 638             Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0      0
# 678            Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch   Ticket      Fare        Cabin Embarked  new_col  new_col1  family
# 13       5   347082   31.2750          NaN        S  sourabh         6       6
# 25       5   347077   31.3875          NaN        S  sourabh         6       6
# 167      4   347088   27.9000          NaN        S  sourabh         5       5
# 360      4   347088   27.9000          NaN        S  sourabh         5       5
# 438      4    19950  263.0000  C23 C25 C27        S  sourabh         5       5
# 567      4   349909   21.0750          NaN        S  sourabh         4       4
# 610      5   347082   31.2750          NaN        S  sourabh         6       6
# 638      5  3101295   39.6875          NaN        S  sourabh         5       5
# 678      6  CA 2144   46.9000          NaN        S  sourabh         7       7
# 885      5   382652   29.1250          NaN        Q  sourabh         5       5

# %%
len(df[df['Parch'] > 53])
# Out:
# 0

# %%
df['Survived']==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
# How many passengers who survived paid the maximum fare ?

# %%
# How many passengers who didnt survived was from class 1 ?

#df[(df[df['Survived']==0]) & (df['Pclass']==1)]

# %%
# How many passengers are having children(<5 years old)

# %%
# Access df rows >> 1) implicit index and 2) is explicit index

df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# 95                        Shorney, Mr. Charles Joseph    male   NaN      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
# 97                    Greenfield, Mr. William Bertram    male  23.0      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 99                                  Kantor, Mr. Sinai    male  34.0      1
#
#     Parch            Ticket     Fare    Cabin Embarked  new_col  new_col1  \
# 0       0         A/5 21171   7.2500      NaN        S  sourabh         1
# 1       0          PC 17599  71.2833      C85        C  sourabh         1
# 2       0  STON/O2. 3101282   7.9250      NaN        S  sourabh         0
# 3       0            113803  53.1000     C123        S  sourabh         1
# 4       0            373450   8.0500      NaN        S  sourabh         0
# ..    ...               ...      ...      ...      ...      ...       ...
# 95      0            374910   8.0500      NaN        S  sourabh         0
# 96      0          PC 17754  34.6542       A5        C  sourabh         0
# 97      1          PC 17759  63.3583  D10 D12        C  sourabh         1
# 98      1            231919  23.0000      NaN        S  sourabh         1
# 99      0            244367  26.0000      NaN        S  sourabh         1
#
#     family
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# ..     ...
# 95       0
# 96       0
# 97       1
# 98       1
# 99       1
#
# [100 rows x 15 columns]

# %%
df[0:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# 62           63         0       1
# 64           65         0       1
# 66           67         1       2
# 68           69         1       3
# 70           71         0       2
# 72           73         0       2
# 74           75         1       3
# 76           77         0       3
# 78           79         1       2
# 80           81         0       3
# 82           83         1       3
# 84           85         1       2
# 86           87         0       3
# 88           89         1       1
# 90           91         0       3
# 92           93         0       1
# 94           95         0       3
# 96           97         0       1
# 98           99         1       2
#
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.00      1
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 4                            Allen, Mr. William Henry    male  35.00      0
# 6                             McCarthy, Mr. Timothy J    male  54.00      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 12                     Saundercock, Mr. William Henry    male  20.00      0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0
# 16                               Rice, Master. Eugene    male   2.00      4
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# 20                               Fynney, Mr. Joseph J    male  35.00      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.00      0
# 24                      Palsson, Miss. Torborg Danira  female   8.00      3
# 26                            Emir, Mr. Farred Chehab    male    NaN      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female    NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.00      0
# 32                           Glynn, Miss. Mary Agatha  female    NaN      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.00      1
# 36                                   Mamee, Mr. Hanna    male    NaN      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.00      2
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00      1
# 42                                Kraeff, Mr. Theodor    male    NaN      0
# 44                      Devaney, Miss. Margaret Delia  female  19.00      0
# 46                                  Lennon, Mr. Denis    male    NaN      1
# 48                                Samaan, Mr. Youssef    male    NaN      2
# 50                         Panula, Master. Juha Niilo    male   7.00      4
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.00      0
# 56                                  Rugg, Miss. Emily  female  21.00      0
# 58                       West, Miss. Constance Mirium  female   5.00      1
# 60                              Sirayanian, Mr. Orsen    male  22.00      0
# 62                        Harris, Mr. Henry Birkhardt    male  45.00      1
# 64                              Stewart, Mr. Albert A    male    NaN      0
# 66                       Nye, Mrs. (Elizabeth Ramell)  female  29.00      0
# 68                    Andersson, Miss. Erna Alexandra  female  17.00      4
# 70                         Jenkin, Mr. Stephen Curnow    male  32.00      0
# 72                               Hood, Mr. Ambrose Jr    male  21.00      0
# 74                                      Bing, Mr. Lee    male  32.00      0
# 76                                  Staneff, Mr. Ivan    male    NaN      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
# 80                               Waelens, Mr. Achille    male  22.00      0
# 82                     McDermott, Miss. Brigdet Delia  female    NaN      0
# 84                                Ilett, Miss. Bertha  female  17.00      0
# 86                             Ford, Mr. William Neal    male  16.00      1
# 88                         Fortune, Miss. Mabel Helen  female  23.00      3
# 90                               Christmann, Mr. Emil    male  29.00      0
# 92                        Chaffee, Mr. Herbert Fuller    male  46.00      1
# 94                                  Coxon, Mr. Daniel    male  59.00      0
# 96                          Goldschmidt, Mr. George B    male  71.00      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.00      0
#
#     Parch            Ticket      Fare        Cabin Embarked  new_col  \
# 0       0         A/5 21171    7.2500          NaN        S  sourabh
# 2       0  STON/O2. 3101282    7.9250          NaN        S  sourabh
# 4       0            373450    8.0500          NaN        S  sourabh
# 6       0             17463   51.8625          E46        S  sourabh
# 8       2            347742   11.1333          NaN        S  sourabh
# 10      1           PP 9549   16.7000           G6        S  sourabh
# 12      0         A/5. 2151    8.0500          NaN        S  sourabh
# 14      0            350406    7.8542          NaN        S  sourabh
# 16      1            382652   29.1250          NaN        Q  sourabh
# 18      0            345763   18.0000          NaN        S  sourabh
# 20      0            239865   26.0000          NaN        S  sourabh
# 22      0            330923    8.0292          NaN        Q  sourabh
# 24      1            349909   21.0750          NaN        S  sourabh
# 26      0              2631    7.2250          NaN        C  sourabh
# 28      0            330959    7.8792          NaN        Q  sourabh
# 30      0          PC 17601   27.7208          NaN        C  sourabh
# 32      0            335677    7.7500          NaN        Q  sourabh
# 34      0          PC 17604   82.1708          NaN        C  sourabh
# 36      0              2677    7.2292          NaN        C  sourabh
# 38      0            345764   18.0000          NaN        S  sourabh
# 40      0              7546    9.4750          NaN        S  sourabh
# 42      0            349253    7.8958          NaN        C  sourabh
# 44      0            330958    7.8792          NaN        Q  sourabh
# 46      0            370371   15.5000          NaN        Q  sourabh
# 48      0              2662   21.6792          NaN        C  sourabh
# 50      1           3101295   39.6875          NaN        S  sourabh
# 52      0          PC 17572   76.7292          D33        C  sourabh
# 54      1            113509   61.9792          B30        C  sourabh
# 56      0        C.A. 31026   10.5000          NaN        S  sourabh
# 58      2        C.A. 34651   27.7500          NaN        S  sourabh
# 60      0              2669    7.2292          NaN        C  sourabh
# 62      0             36973   83.4750          C83        S  sourabh
# 64      0          PC 17605   27.7208          NaN        C  sourabh
# 66      0        C.A. 29395   10.5000          F33        S  sourabh
# 68      2           3101281    7.9250          NaN        S  sourabh
# 70      0        C.A. 33111   10.5000          NaN        S  sourabh
# 72      0      S.O.C. 14879   73.5000          NaN        S  sourabh
# 74      0              1601   56.4958          NaN        S  sourabh
# 76      0            349208    7.8958          NaN        S  sourabh
# 78      2            248738   29.0000          NaN        S  sourabh
# 80      0            345767    9.0000          NaN        S  sourabh
# 82      0            330932    7.7875          NaN        Q  sourabh
# 84      0        SO/C 14885   10.5000          NaN        S  sourabh
# 86      3        W./C. 6608   34.3750          NaN        S  sourabh
# 88      2             19950  263.0000  C23 C25 C27        S  sourabh
# 90      0            343276    8.0500          NaN        S  sourabh
# 92      0       W.E.P. 5734   61.1750          E31        S  sourabh
# 94      0            364500    7.2500          NaN        S  sourabh
# 96      0          PC 17754   34.6542           A5        C  sourabh
# 98      1            231919   23.0000          NaN        S  sourabh
#
#     new_col1  family
# 0          1       1
# 2          0       0
# 4          0       0
# 6          0       0
# 8          2       2
# 10         2       2
# 12         0       0
# 14         0       0
# 16         5       5
# 18         1       1
# 20         0       0
# 22         0       0
# 24         4       4
# 26         0       0
# 28         0       0
# 30         0       0
# 32         0       0
# 34         1       1
# 36         0       0
# 38         2       2
# 40         1       1
# 42         0       0
# 44         0       0
# 46         1       1
# 48         2       2
# 50         5       5
# 52         1       1
# 54         1       1
# 56         0       0
# 58         3       3
# 60         0       0
# 62         1       1
# 64         0       0
# 66         0       0
# 68         6       6
# 70         0       0
# 72         0       0
# 74         0       0
# 76         0       0
# 78         2       2
# 80         0       0
# 82         0       0
# 84         0       0
# 86         4       4
# 88         5       5
# 90         0       0
# 92         1       1
# 94         0       0
# 96         0       0
# 98         1       1

# %%
df.iloc[0:2] # strat from 0 and goes to 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_col1  family
# 0      0  A/5 21171   7.2500   NaN        S  sourabh         1       1
# 1      0   PC 17599  71.2833   C85        C  sourabh         1       1

# %%
df.loc[0:2] # gives the rows whoes name is o ,1,2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1  family
# 0      0         A/5 21171   7.2500   NaN        S  sourabh         1       1
# 1      0          PC 17599  71.2833   C85        C  sourabh         1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  sourabh         0       0

# %%
df.loc[0:2,['Name','Sex','Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
df.iloc[0:2,3:5]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
len(df['Name'][2:5])
# Out:
# 3

# %%
s = pd.Series(list(df["Name"][2:5]), index = ['a','b','c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]))

# %%
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
s.append(s1)
# Out:
# /tmp/ipykernel_2087/137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# 0                                Moran, Mr. James
# 1                         McCarthy, Mr. Timothy J
# 2                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
df.drop('PassengerId', axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      new_col  new_col1  family
# 0    sourabh         1       1
# 1    sourabh         1       1
# 2    sourabh         0       0
# 3    sourabh         1       1
# 4    sourabh         0       0
# ..       ...       ...     ...
# 886  sourabh         0       0
# 887  sourabh         0       0
# 888  sourabh         3       3
# 889  sourabh         0       0
# 890  sourabh         0       0
#
# [891 rows x 14 columns]

# %%
df.drop(1, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ..                                            ...     ...   ...    ...    ...
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                         Behr, Mr. Karl Howell    male  26.0      0      0
# 890                           Dooley, Mr. Patrick    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  new_col  new_col1  family
# 0           A/5 21171   7.2500   NaN        S  sourabh         1       1
# 2    STON/O2. 3101282   7.9250   NaN        S  sourabh         0       0
# 3              113803  53.1000  C123        S  sourabh         1       1
# 4              373450   8.0500   NaN        S  sourabh         0       0
# 5              330877   8.4583   NaN        Q  sourabh         0       0
# ..                ...      ...   ...      ...      ...       ...     ...
# 886            211536  13.0000   NaN        S  sourabh         0       0
# 887            112053  30.0000   B42        S  sourabh         0       0
# 888        W./C. 6607  23.4500   NaN        S  sourabh         3       3
# 889            111369  30.0000  C148        C  sourabh         0       0
# 890            370376   7.7500   NaN        Q  sourabh         0       0
#
# [890 rows x 15 columns]

# %%
df.set_index('Name',inplace = True)

# %%
df.loc['Allen, Mr. William Henry']
# Out:
# PassengerId          5
# Survived             0
# Pclass               3
# Sex               male
# Age               35.0
# SibSp                0
# Parch                0
# Ticket          373450
# Fare              8.05
# Cabin              NaN
# Embarked             S
# new_col        sourabh
# new_col1             0
# family               0
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.iloc[3]
# Out:
# PassengerId          5
# Survived             0
# Pclass               3
# Sex               male
# Age               35.0
# SibSp                0
# Parch                0
# Ticket          373450
# Fare              8.05
# Cabin              NaN
# Embarked             S
# new_col        sourabh
# new_col1             0
# family               0
# Name: Allen, Mr. William Henry, dtype: object

# %%
d = {"key1": [2,3,4,5],
     "key2": [4,5,6,7],
     "key3": [2,3,4,5]
}

# %%
d
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 4, 5]}

# %%
import pandas as pd
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (890, 14)

# %%
df1.info
# Out:
# <bound method DataFrame.info of     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]>

# %%
df1.dtypes
# Out:
# taxonomy_id    object
# name           object
# parent_id      object
# parent_name    object
# dtype: object

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis=1) # for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
df1.fillna("missing_value_here")
# Out:
#     taxonomy_id                          name           parent_id  \
# 0           101                     Emergency  missing_value_here
# 1        101-01             Disaster Response                 101
# 2        101-02                Emergency Cash                 101
# 3     101-02-01             Help Pay for Food              101-02
# 4     101-02-02       Help Pay for Healthcare              101-02
# ..          ...                           ...                 ...
# 285   111-01-07              Workplace Rights              111-01
# 286      111-02                     Mediation                 111
# 287      111-03                        Notary                 111
# 288      111-04                Representation                 111
# 289      111-05  Translation & Interpretation                 111
#
#               parent_name
# 0      missing_value_here
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# 286                 Legal
# 287                 Legal
# 288                 Legal
# 289                 Legal
#
# [290 rows x 4 columns]

# %%
# what is the average fare paid by people who survived?

df.groupby('Survived').mean()
# Out:
# /tmp/ipykernel_2087/2342093408.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          445.665689  1.953079  28.310277  0.472141  0.466276  48.328288
#
#           new_col1    family
# Survived
# 0         0.883424  0.883424
# 1         0.938416  0.938416

# %%
df.groupby('Survived').max()
# Out:
# /tmp/ipykernel_2087/123491824.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Survived').max()
#           PassengerId  Pclass   Sex   Age  SibSp  Parch     Ticket      Fare  \
# Survived
# 0                 891       3  male  74.0      8      6  WE/P 5735  263.0000
# 1                 890       3  male  80.0      4      5  WE/P 5735  512.3292
#
#           new_col  new_col1  family
# Survived
# 0         sourabh        10      10
# 1         sourabh         6       6

# %%
df.groupby('Survived').min()
# Out:
# /tmp/ipykernel_2087/2003144291.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby('Survived').min()
#           PassengerId  Pclass     Sex   Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                   1       1  female  1.00      0      0  110413   0.0
# 1                   3       1  female  0.42      0      0  110152   0.0
#
#           new_col  new_col1  family
# Survived
# 0         sourabh         0       0
# 1         sourabh         0       0

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                           \
#                count        mean         std  min    25%    50%    75%    max
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.0  455.0  675.0  891.0
# 1              341.0  445.665689  251.585069  3.0  256.0  441.0  652.0  890.0
#
#          Pclass            ... new_col1       family                           \
#           count      mean  ...      75%   max  count      mean       std  min
# Survived                   ...
# 0         549.0  2.531876  ...      1.0  10.0  549.0  0.883424  1.830669  0.0
# 1         341.0  1.953079  ...      2.0   6.0  341.0  0.938416  1.187814  0.0
#
#
#           25%  50%  75%   max
# Survived
# 0         0.0  0.0  1.0  10.0
# 1         0.0  1.0  2.0   6.0
#
# [2 rows x 64 columns]

# %%
df.groupby('Survived').aggregate([min,'max', 'mean', 'median', 'count', np.std])
# Out:
# /tmp/ipykernel_2087/2564472994.py:1: FutureWarning: ['Sex', 'Ticket', 'Cabin', 'Embarked', 'new_col'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Survived').aggregate([min,'max', 'mean', 'median', 'count', np.std])
#          PassengerId                                           Pclass      \
#                  min  max        mean median count         std    min max
# Survived
# 0                  1  891  447.016393  455.0   549  260.640469      1   3
# 1                  3  890  445.665689  441.0   341  251.585069      1   3
#
#                            ...  new_col1                        family      \
#               mean median  ...      mean median count       std    min max
# Survived                   ...
# 0         2.531876    3.0  ...  0.883424    0.0   549  1.830669      0  10
# 1         1.953079    2.0  ...  0.938416    1.0   341  1.187814      0   6
#
#
#               mean median count       std
# Survived
# 0         0.883424    0.0   549  1.830669
# 1         0.938416    1.0   341  1.187814
#
# [2 rows x 48 columns]

# %%
# groupby with two columns

# Avg people who survived for each sex, Pclass

df.groupby(['Sex', 'Pclass'])['Survived'].mean()
# Out:
# Sex     Pclass
# female  1         0.967742
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47
